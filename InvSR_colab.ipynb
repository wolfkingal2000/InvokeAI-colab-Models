# %% [markdown]
# <a href="https://colab.research.google.com/github/wolfkingal2000/InvokeAI-colab-Models/blob/main/InvSR_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone https://huggingface.co/spaces/OAOA/InvSR
# %cd /content/InvSR
# !pip install -r requirements.txt -q spaces
# !wget -O /content/InvSR/app.py https://raw.githubusercontent.com/zsyOAOA/InvSR/master/app.py
# !sed -i 's/share=False/share=True/' app.py

# %%
import torch
torch.cuda.empty_cache()
# %cd /content/InvSR
# !python app.py
